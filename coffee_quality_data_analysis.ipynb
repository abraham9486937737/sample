# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import warnings
import re
import ast
import matplotlib.pyplot as plt
import seaborn as sns

# %%
warnings.filterwarnings('ignore')

# %%
pd.describe_option('display.max.columns', None)
pd.describe_option('display.max.rows', None)
# Out:
# "display.max_rows : int\n    If max_rows is exceeded, switch to truncate view. Depending on\n    `large_repr`, objects are either centrally truncated or printed as\n    a summary view. 'None' value means unlimited.\n\n    In case python/IPython is running in a terminal and `large_repr`\n    equals 'truncate' this can be set to 0 and pandas will auto-detect\n    the height of the terminal and print a truncated object which fits\n    the screen height. The IPython notebook, IPython qtconsole, or\n    IDLE do not run in a terminal and hence it is not possible to do\n    correct auto-detection.\n    [default: 60] [currently: 60]"

# %% [markdown]
# ## Data Import

# %%
df = pd.read_csv('E:\DA&DS_Files\Python\Reinforcement Project - Python\Coffee Quality Dataset\coffeeQuality.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Species                     Owner Country.of.Origin  \
# 0           0  Arabica                 metad plc          Ethiopia
# 1           1  Arabica                 metad plc          Ethiopia
# 2           2  Arabica  grounds for health admin         Guatemala
# 3           3  Arabica       yidnekachew dabessa          Ethiopia
# 4           4  Arabica                 metad plc          Ethiopia
#
#                                   Farm.Name Lot.Number       Mill ICO.Number  \
# 0                                 metad plc        NaN  metad plc  2014/2015
# 1                                 metad plc        NaN  metad plc  2014/2015
# 2  san marcos barrancas "san cristobal cuch        NaN        NaN        NaN
# 3     yidnekachew dabessa coffee plantation        NaN    wolensu        NaN
# 4                                 metad plc        NaN  metad plc  2014/2015
#
#                                  Company       Altitude  ...  Color  \
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0  Number.of.Bags        Aroma       Flavor   Aftertaste  \
# count  1339.000000     1338.000000  1339.000000  1339.000000  1339.000000
# mean    669.000000      159.085202     7.770187     7.520426     7.401083
# std     386.680316      173.698167     5.534440     0.398442     0.404463
# min       0.000000        0.000000     0.000000     0.000000     0.000000
# 25%     334.500000       14.000000     7.420000     7.330000     7.250000
# 50%     669.000000      175.000000     7.580000     7.580000     7.420000
# 75%    1003.500000      275.000000     7.750000     7.750000     7.580000
# max    1338.000000     3200.000000   200.000000     8.830000     8.670000
#
#            Acidity         Body      Balance   Uniformity    Clean.Cup  \
# count  1339.000000  1339.000000  1339.000000  1339.000000  1339.000000
# mean      7.535706     7.517498     7.518013     9.834877     9.835108
# std       0.379827     0.370064     0.408943     0.554591     0.763946
# ...

# %% [markdown]
# ## Data Analysis

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                  0
# Species                     0
# Owner                       7
# Country.of.Origin           1
# Farm.Name                 359
# Lot.Number               1063
# Mill                      318
# ICO.Number                159
# Company                   209
# Altitude                  226
# Region                     59
# Producer                  232
# Number.of.Bags              1
# Bag.Weight                  0
# In.Country.Partner          0
# Harvest.Year               47
# Grading.Date                0
# Owner.1                     7
# Variety                   226
# Processing.Method         170
# Aroma                       0
# Flavor                      0
# Aftertaste                  0
# Acidity                     0
# Body                        0
# Balance                     0
# Uniformity                  0
# Clean.Cup                   0
# Sweetness                   0
# Cupper.Points               0
# Total.Cup.Points            0
# ...

# %%
#to view all columns use the below code from pandas
#pd.set_option('display.max.columns', None)
#view dataframe columns and its datatypes
#df.info()
pd.DataFrame({'Column Name': df.columns, 'Data Type': df.dtypes})
# Out:
#                                  Column Name Data Type
# Unnamed: 0                        Unnamed: 0     int64
# Species                              Species    object
# Owner                                  Owner    object
# Country.of.Origin          Country.of.Origin    object
# Farm.Name                          Farm.Name    object
# Lot.Number                        Lot.Number    object
# Mill                                    Mill    object
# ICO.Number                        ICO.Number    object
# Company                              Company    object
# Altitude                            Altitude    object
# Region                                Region    object
# Producer                            Producer    object
# Number.of.Bags                Number.of.Bags   float64
# Bag.Weight                        Bag.Weight    object
# In.Country.Partner        In.Country.Partner    object
# Harvest.Year                    Harvest.Year    object
# ...

# %% [markdown]
# ## Creating new column list for Quality Measures, Bean Metadata and Farm Metadata

# %%
quality_measure_columns = ['Aroma', 'Flavor', 'Aftertaste', 'Acidity', 'Body', 'Balance',
    'Uniformity', 'Clean.Cup', 'Sweetness', 'Moisture', 'Category.One.Defects']
bean_metadata_columns = ['Processing.Method', 'Color', 'Species']
farm_metadata_columns = ['Owner', 'Country.of.Origin', 'Farm.Name', 'Lot.Number', 'Mill',
    'Company', 'Altitude', 'Region']

# %% [markdown]
# ## now creating 3 new data frames from the base data frame (df)

# %%
df_quality = df[quality_measure_columns].copy()
df_bean = df[bean_metadata_columns].copy()
df_farm = df[farm_metadata_columns].copy()

# %%
df_quality.shape
# Out:
# (1339, 11)

# %%
df_bean.shape
# Out:
# (1339, 3)

# %%
df_farm.shape
# Out:
# (1339, 8)

# %%
df_quality.sample(5)
# Out:
#       Aroma  Flavor  Aftertaste  Acidity  Body  Balance  Uniformity  \
# 710    7.75    7.33        7.50     7.50  7.33     7.58        10.0
# 510    7.67    7.67        7.42     7.83  7.50     7.50        10.0
# 160    7.75    7.92        7.67     7.83  7.75     7.67        10.0
# 1010   7.33    7.42        7.25     7.42  7.25     7.17        10.0
# 1057   7.00    7.33        7.50     7.33  7.00     7.33        10.0
#
#       Clean.Cup  Sweetness  Moisture  Category.One.Defects
# 710        10.0       10.0      0.00                     0
# 510        10.0       10.0      0.10                     1
# 160        10.0       10.0      0.10                     0
# 1010       10.0       10.0      0.00                     0
# 1057       10.0       10.0      0.11                     0
